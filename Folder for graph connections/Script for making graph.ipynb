# %%
from math import cos, asin, sqrt, pi

def distance(lat1, lon1, lat2, lon2):
    p = pi/180
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 12742 * asin(sqrt(a)) #2*R*asin...

# %%
import googlemaps
import pandas as pd
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyANpehIgtD1M7TWWQ0CUnfuygnwmSptLMw')

# %%
df = pd.read_csv("Other_List.csv")
# df = pd.read_csv("Kyoto_Sub.csv")
# df = pd.read_csv("Kobe_Sub.csv")
# df = pd.read_csv("Osaka.csv")

# df2 = pd.read_csv("Connections_Kyoto.csv", header=None)
# df2 = pd.read_csv("Connections_Kobe.csv", header=None)
df2 = pd.read_csv("Connections_Others.csv", header=None)
# df2 = pd.read_csv("Connections_Osaka.csv", header=None)

# %%
# # check coordinates 
# print(len(df))
# for i in range(len(df)):
#     geocode_result = gmaps.geocode(df["Name"][i] + " station")
#     df["lat"][i] = geocode_result[0]['geometry']['location']['lat']
#     df["lng"][i] = geocode_result[0]['geometry']['location']['lng']

# %%
#outptu csv
"""
# df.to_csv("Other_List.csv", index=False)
# df.to_csv("Kyoto_Sub.csv", index=False)
# df.to_csv("Kobe_Sub.csv", index=False)
# df.to_csv("Osaka.csv", index=False)
"""

# %%
# # Create Stations
for i in range(len(df)):
    print(F"Create (n:Station{{name:'{(df['Name'][i])}', lat:{df['lat'][i]}, lng:{df['lng'][i]}}});")
# Out:
# Create (n:Station{name:'Wakayama', lat:34.2321803, lng:135.1917916});
# Create (n:Station{name:'Kishi', lat:34.2093468, lng:135.3120752});
# Create (n:Station{name:'Gobo', lat:33.9077129, lng:135.1591588});
# Create (n:Station{name:'Nishigobo', lat:33.8867441, lng:135.1529776});
# Create (n:Station{name:'Mizumakannon', lat:34.4034966, lng:135.3855514});
# Create (n:Station{name:'Kaizuka', lat:34.4454668, lng:135.3575322});
# Create (n:Station{name:'Hamaderaekimae', lat:34.541302, lng:135.4431877});
# Create (n:Station{name:'Sumiyoshitorii-mae', lat:34.6126411, lng:135.4912307});
# Create (n:Station{name:'Shin-Imamiya', lat:34.6497931, lng:135.5015478});
# Create (n:Station{name:'Kaminoki', lat:34.6158318, lng:135.4970568});
# Create (n:Station{name:'Abeno', lat:34.642719, lng:135.5120601});
# Create (n:Station{name:'Senbonguchi', lat:34.3751, lng:135.854});
# Create (n:Station{name:'Yoshinoyama', lat:34.356433, lng:135.870617});
# ...

# %%
#reshape column to row
def Get_lat_long(val):
    specific = df.loc[df["Name"] == val]
    lat, lng = specific["lat"].values[0], specific["lng"].values[0]
    return lat, lng

# %%
def Get(n, m):

    Operator = "JR pass"
    # railway = "Kyoto_Municipal_Subway"
    # railway = "Kobe_Municipal_Subway"
    railway = "Osaka_Metro"

    nlat, nlng = Get_lat_long(n)
    mlat, mlng = Get_lat_long(m)
    dist = distance(nlat, nlng, mlat, mlng)
    print( f"""match (n:Station{{name: '{n}'}}), (m:Station{{name: '{m}'}}) 
    create (n)-[:Connected{{distance:{dist}, Operator:'{Operator}', Railway:'{railway}'}}]->(m);\n""")

# %%
# create relationship
for i in range(len(df2)):
    Get(df2[0][i], df2[1][i])
# Out:
# match (n:Station{name: 'Senbonguchi'}), (m:Station{name: 'Yoshinoyama'})
#     create (n)-[:Connected{distance:2.5757885226555643, Operator:'JR pass', Railway:'Osaka_Metro'}]->(m);

# %%
#For the others lines

df = pd.read_csv("Other_List.csv")
df2 = pd.read_csv("Connections_Others.csv", header=None)


def Get_Others(df2, n, m):

    Operator = "JR pass"
    railway = df2[2][i]

    nlat, nlng = Get_lat_long(n)
    mlat, mlng = Get_lat_long(m)
    dist = distance(nlat, nlng, mlat, mlng)
    print( f"""match (n:Station{{name: '{n}'}}), (m:Station{{name: '{m}'}}) 
    create (n)-[:Connected{{distance:{dist}, Operator:'{Operator}', Railway:'{railway}'}}]->(m);\n""")

df2[2]

for i in range(len(df2)):
    Get_Others(df2, df2[0][i], df2[1][i])
# Out:
# match (n:Station{name: 'Senbonguchi'}), (m:Station{name: 'Yoshinoyama'})
#     create (n)-[:Connected{distance:2.5757885226555643, Operator:'JR pass', Railway:'Yoshinoyama Ropeway'}]->(m);
#
# match (n:Station{name: 'Wakayama'}), (m:Station{name: 'Kishi'})
#     create (n)-[:Connected{distance:11.347115877654337, Operator:'JR pass', Railway:'Wakayama Electric Railway Kishigawa Line'}]->(m);
#
# match (n:Station{name: 'Gobo'}), (m:Station{name: 'Nishigobo'})
#     create (n)-[:Connected{distance:2.4004046906415364, Operator:'JR pass', Railway:'Kishi Railway'}]->(m);
#
# match (n:Station{name: 'Kaizuka'}), (m:Station{name: 'Mizumakannon'})
#     create (n)-[:Connected{distance:5.327703810633776, Operator:'JR pass', Railway:'Mizuma Railway'}]->(m);
#
# match (n:Station{name: 'Hamaderaekimae'}), (m:Station{name: 'Sumiyoshitorii-mae'})
#     create (n)-[:Connected{distance:9.070408910052485, Operator:'JR pass', Railway:'Hankai Tramway Hankai Line'}]->(m);
#
# ...

# %%
lat1, long1, lat2, long2 = 34.668838323971805, 135.15168278415086, 34.6793545,135.1672304

print(distance(lat1, long1, lat2, long2))
# Out:
# 1.8408771586872654
